# %%
# Ryan Cummings, CMPE 255: Preliminary Analysis, Nov 2 2021.

# %% [markdown]
# ### Libraries:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import plotly.express as px
import seaborn as sns

# %% [markdown]
# # Loading in the Data

# %%
data = pd.read_csv("AviationData.txt", sep="|")
#data.to_csv("255Airplane.csv")

# %%
data.head()
# Out:
#          Event Id   Investigation Type   Accident Number    Event Date   \
# 0  20131208X92103             Accident        ERA14FA068    12/08/2013
# 1  20131206X95526             Accident        ERA14FA066    12/06/2013
# 2  20131205X60841             Accident        ANC14CA010    12/04/2013
# 3  20131204X65412             Accident        ERA14CA062    12/03/2013
# 4  20131202X34203             Accident        ERA14LA059    12/02/2013
#
#               Location          Country     Latitude     Longitude   \
# 0     Jacksonville, FL    United States    30.319723    -81.514167
# 1          Sebring, FL    United States    27.463333    -81.366667
# 2         Soldotna, AK    United States
# 3   Hendersonville, NC    United States
# 4          Trenton, SC    United States    33.736944    -81.818611
#
#    Airport Code                      Airport Name   ...  Air Carrier   \
# 0           CRG    Jacksonville Executive Airport   ...
# 1           SEF          Sebring Regional Airport   ...
# 2                                                   ...
# 3                                                   ...
# 4           6J6          Edgefield County Airport   ...
#
#    Total Fatal Injuries   Total Serious Injuries   Total Minor Injuries   \
# 0                     3
# 1                     1
# 2
# 3
# 4                                                                     1
#
#    Total Uninjured   Weather Condition   Broad Phase of Flight   \
# 0                                  IMC
# 1
# 2
# 3
# 4
#
#    Report Status   Publication Date
# 0    Preliminary         12/13/2013
# 1    Preliminary         12/13/2013
# 2    Preliminary
# 3    Preliminary
# 4    Preliminary         12/13/2013
#
# [5 rows x 32 columns]

# %%
data.columns
# Out:
# Index(['Event Id ', ' Investigation Type ', ' Accident Number ',
#        ' Event Date ', ' Location ', ' Country ', ' Latitude ', ' Longitude ',
#        ' Airport Code ', ' Airport Name ', ' Injury Severity ',
#        ' Aircraft Damage ', ' Aircraft Category ', ' Registration Number ',
#        ' Make ', ' Model ', ' Amateur Built ', ' Number of Engines ',
#        ' Engine Type ', ' FAR Description ', ' Schedule ',
#        ' Purpose of Flight ', ' Air Carrier ', ' Total Fatal Injuries ',
#        ' Total Serious Injuries ', ' Total Minor Injuries ',
#        ' Total Uninjured ', ' Weather Condition ', ' Broad Phase of Flight ',
#        ' Report Status ', ' Publication Date ', ' '],
#       dtype='object')

# %% [markdown]
# ### Right off the bat we can take a look at the columns and infer on which columns can be dropped for being unnecessary. From looking at the data some columns that we can drop are: Event ID, Accident Number, Registration Number, FAR Description.

# %%
data.drop(['Event Id ', ' Accident Number ', ' Registration Number ', ' FAR Description ', ' Report Status '], inplace = True, axis=1)

# %%
data.head()
# Out:
#    Investigation Type    Event Date              Location          Country   \
# 0            Accident    12/08/2013      Jacksonville, FL    United States
# 1            Accident    12/06/2013           Sebring, FL    United States
# 2            Accident    12/04/2013          Soldotna, AK    United States
# 3            Accident    12/03/2013    Hendersonville, NC    United States
# 4            Accident    12/02/2013           Trenton, SC    United States
#
#      Latitude     Longitude   Airport Code                      Airport Name   \
# 0   30.319723    -81.514167            CRG    Jacksonville Executive Airport
# 1   27.463333    -81.366667            SEF          Sebring Regional Airport
# 2
# 3
# 4   33.736944    -81.818611            6J6          Edgefield County Airport
#
#    Injury Severity   Aircraft Damage   ...  Purpose of Flight   Air Carrier   \
# 0         Fatal(3)       Substantial   ...           Personal
# 1         Fatal(1)         Destroyed   ...        Positioning
# 2                                      ...
# 3                                      ...
# 4        Non-Fatal       Substantial   ...           Personal
#
#    Total Fatal Injuries   Total Serious Injuries   Total Minor Injuries   \
# 0                     3
# 1                     1
# 2
# 3
# 4                                                                     1
#
#    Total Uninjured   Weather Condition   Broad Phase of Flight   \
# 0                                  IMC
# 1
# 2
# 3
# 4
#
#    Publication Date
# 0        12/13/2013
# 1        12/13/2013
# 2
# 3
# 4        12/13/2013
#
# [5 rows x 27 columns]

# %% [markdown]
# ### Reasoning for Dropping:
# ### - Event Id -> Dropping because it was a unique identifier for the instance (accident/incident).  This would not be helpful for any type of analysis
# ### - Accident Number -> Similar to above, I removed it because it was a unique identifier for the accident and it would not be helpful for analysis.
# ### - Registration Number -> This was the registration number associated with the aircraft. Again, not useful since it is a unique identifier.
# ### - FAR Description -> This is the authority the aircraft was operating under at the time of the accident. This is something that we can look at a later time, but for now we don't need it for our analysis.
# ### Report Status -> This is the furthest level to which a report has been completed. Which is not helpful in our analysis.
#
# More info on the columns and their descriptions can be seen at: https://www.ntsb.gov/_layouts/15/ntsb.aviation/AviationDownloadDataDictionary.aspx

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# Just from the quick previews up above we can see that there is alot of missing values. I want to see how these values are being represented, is it an empty string? NaN? I explore this further below:

# %%
data[' Air Carrier '].values
# Out:
# array(['  ', '  ', '  ', ..., '  ', '  ', '  '], dtype=object)

# %% [markdown]
# As we can see the missing values are represented with two spaces ('  '). Now I am going to go through the df and replace all the double spaces with NaN.

# %%
data.replace("  ", np.NaN, inplace = True)
data.head()
# Out:
#    Investigation Type    Event Date              Location          Country   \
# 0            Accident    12/08/2013      Jacksonville, FL    United States
# 1            Accident    12/06/2013           Sebring, FL    United States
# 2            Accident    12/04/2013          Soldotna, AK    United States
# 3            Accident    12/03/2013    Hendersonville, NC    United States
# 4            Accident    12/02/2013           Trenton, SC    United States
#
#      Latitude     Longitude   Airport Code                      Airport Name   \
# 0   30.319723    -81.514167            CRG    Jacksonville Executive Airport
# 1   27.463333    -81.366667            SEF          Sebring Regional Airport
# 2          NaN           NaN            NaN                               NaN
# 3          NaN           NaN            NaN                               NaN
# 4   33.736944    -81.818611            6J6          Edgefield County Airport
#
#    Injury Severity   Aircraft Damage   ...  Purpose of Flight   Air Carrier   \
# 0         Fatal(3)       Substantial   ...           Personal            NaN
# 1         Fatal(1)         Destroyed   ...        Positioning            NaN
# 2               NaN               NaN  ...                 NaN           NaN
# 3               NaN               NaN  ...                 NaN           NaN
# 4        Non-Fatal       Substantial   ...           Personal            NaN
#
#    Total Fatal Injuries   Total Serious Injuries   Total Minor Injuries   \
# 0                     3                       NaN                    NaN
# 1                     1                       NaN                    NaN
# 2                    NaN                      NaN                    NaN
# 3                    NaN                      NaN                    NaN
# 4                    NaN                      NaN                     1
#
#    Total Uninjured   Weather Condition   Broad Phase of Flight   \
# 0               NaN                IMC                      NaN
# 1               NaN                 NaN                     NaN
# 2               NaN                 NaN                     NaN
# 3               NaN                 NaN                     NaN
# 4               NaN                 NaN                     NaN
#
#    Publication Date
# 0        12/13/2013
# 1        12/13/2013
# 2                NaN
# 3                NaN
# 4        12/13/2013
#
# [5 rows x 27 columns]

# %% [markdown]
# As a safety check, I am going to drop all the rows which have NaN as every single one of their values. (aka rows that are completely empty):

# %%
data.dropna(axis = 0, how = 'all', inplace = True)

# %%
data
# Out:
#        Investigation Type    Event Date              Location   \
# 0                Accident    12/08/2013      Jacksonville, FL
# 1                Accident    12/06/2013           Sebring, FL
# 2                Accident    12/04/2013          Soldotna, AK
# 3                Accident    12/03/2013    Hendersonville, NC
# 4                Accident    12/02/2013           Trenton, SC
# ...                    ...           ...                   ...
# 74423            Accident    08/30/1974         Saltville, VA
# 74424            Accident    07/19/1962        BRIDGEPORT, CA
# 74425            Accident    10/24/1948       MOOSE CREEK, ID
# 74426            Accident            NaN          Unknown, UN
# 74427            Incident            NaN          Cuzco, Peru
#
#               Country     Latitude     Longitude   Airport Code   \
# 0       United States    30.319723    -81.514167            CRG
# 1       United States    27.463333    -81.366667            SEF
# 2       United States           NaN           NaN            NaN
# 3       United States           NaN           NaN            NaN
# 4       United States    33.736944    -81.818611            6J6
# ...                ...          ...           ...            ...
# 74423   United States    36.922223    -81.878056             NaN
# 74424   United States           NaN           NaN            NaN
# 74425   United States           NaN           NaN            NaN
# 74426   United States           NaN           NaN            NaN
# 74427            Peru           NaN           NaN            NaN
#
#                           Airport Name   Injury Severity   Aircraft Damage   \
# 0       Jacksonville Executive Airport          Fatal(3)       Substantial
# 1             Sebring Regional Airport          Fatal(1)         Destroyed
# 2                                   NaN               NaN               NaN
# 3                                   NaN               NaN               NaN
# 4             Edgefield County Airport         Non-Fatal       Substantial
# ...                                 ...               ...               ...
# 74423                               NaN         Fatal(3)         Destroyed
# 74424                               NaN         Fatal(4)         Destroyed
# 74425                               NaN         Fatal(2)         Destroyed
# 74426                               NaN        Non-Fatal       Substantial
# 74427                               NaN         Incident                NaN
#
#        ...  Purpose of Flight   Air Carrier   Total Fatal Injuries   \
# 0      ...           Personal            NaN                     3
# 1      ...        Positioning            NaN                     1
# 2      ...                 NaN           NaN                    NaN
# 3      ...                 NaN           NaN                    NaN
# 4      ...           Personal            NaN                    NaN
# ...    ...                 ...           ...                    ...
# 74423  ...           Personal            NaN                     3
# 74424  ...           Personal            NaN                     4
# 74425  ...           Personal            NaN                     2
# 74426  ...               PUBF            NaN                    NaN
# 74427  ...                 NaN           NaN                    NaN
#
#        Total Serious Injuries   Total Minor Injuries   Total Uninjured   \
# 0                          NaN                    NaN               NaN
# 1                          NaN                    NaN               NaN
# 2                          NaN                    NaN               NaN
# 3                          NaN                    NaN               NaN
# 4                          NaN                     1                NaN
# ...                        ...                    ...               ...
# 74423                      NaN                    NaN               NaN
# 74424                       0                      0                 0
# 74425                       0                      0                 0
# 74426                      NaN                    NaN                1
# 74427                      NaN                    NaN               NaN
#
#        Weather Condition   Broad Phase of Flight   Publication Date
# 0                    IMC                      NaN        12/13/2013
# 1                     NaN                     NaN        12/13/2013
# 2                     NaN                     NaN                NaN
# 3                     NaN                     NaN                NaN
# 4                     NaN                     NaN        12/13/2013
# ...                   ...                     ...                ... ..
# 74423                IMC                  CRUISE         02/26/2007
# 74424                UNK                 UNKNOWN         09/19/1996
# 74425                UNK                  CRUISE                 NaN
# 74426                 NaN                     NaN        02/08/2013
# 74427                 NaN                     NaN        07/12/2001
#
# [74428 rows x 27 columns]

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# The next thing that I want to do is get the data prepped to be used in possible algorithms such as: Regression, Decision Trees, and Clustering. Feature selection and preperation is important because key insights can be missed because of uncleaned data. For example, the first thing that I want to do is seperate the Date column into 3 columns: Month, Day, Year. I feel that this is important because we are looking at aircraft accidents and there may be more accidents during the winter time of year for example. So extracting month, in this example, is important because if we are going to build some models and this feature may be a key influencer.
#
# Another feature that I want to extract more info from is the column: 'Injury Severity'. This column consists of the type of injury that occured, in this case it has the values: Fatal, Non-Fatal, Incident, and Unavailable. I want to clean this column because it has values such as: Fatal(14), Fatal(7). I want to take away the number that is in the paranthesis, which is the number of fatalities, and just have it be Fatal. The number of fatalities is seen in another column which makes it redundant to have it again here.
#
# Along with this, I want to seperate the 'Location' column. I want to seperate it because it is composed of city and state in the format of 'City,State'. Having these as seperate columns will be potentially helpful when creating a model.
#
# These 3 feature engineering decisions are seen below:

# %% [markdown]
# ### Date

# %%
# Date
data[['Month','Day','Year']] = data[' Event Date '].str.split('/',expand=True)

# %%
data[[' Event Date ','Month','Day','Year']].head()
# Out:
#     Event Date  Month Day   Year
# 0   12/08/2013     12  08  2013
# 1   12/06/2013     12  06  2013
# 2   12/04/2013     12  04  2013
# 3   12/03/2013     12  03  2013
# 4   12/02/2013     12  02  2013

# %% [markdown]
# ### Injury Severity

# %%
# Injury Severity
lst = []
for i in data[' Injury Severity ']:
    try:
        if i == np.NaN:
            lst.append(np.NaN)
            continue
        if 'Fatal(' in i:
            lst.append(i[0:-4])
        else:
            lst.append(i)
    except:
        continue

# %%
len(lst)
# Out:
# 74372

# %%
# Injury Severity
severity_lst = []
counter = 0
for i in (pd.isna(data[' Injury Severity ']) == False):
    if i == True:
        severity_lst.append(lst[counter])
        counter += 1
    if i == False:
        severity_lst.append(np.NaN)

# %%
len(severity_lst)
# Out:
# 74428

# %%
data[' Injury Severity '] = severity_lst
data.head()
# Out:
#    Investigation Type    Event Date              Location          Country   \
# 0            Accident    12/08/2013      Jacksonville, FL    United States
# 1            Accident    12/06/2013           Sebring, FL    United States
# 2            Accident    12/04/2013          Soldotna, AK    United States
# 3            Accident    12/03/2013    Hendersonville, NC    United States
# 4            Accident    12/02/2013           Trenton, SC    United States
#
#      Latitude     Longitude   Airport Code                      Airport Name   \
# 0   30.319723    -81.514167            CRG    Jacksonville Executive Airport
# 1   27.463333    -81.366667            SEF          Sebring Regional Airport
# 2          NaN           NaN            NaN                               NaN
# 3          NaN           NaN            NaN                               NaN
# 4   33.736944    -81.818611            6J6          Edgefield County Airport
#
#    Injury Severity   Aircraft Damage   ...  Total Serious Injuries   \
# 0             Fatal      Substantial   ...                      NaN
# 1             Fatal        Destroyed   ...                      NaN
# 2               NaN               NaN  ...                      NaN
# 3               NaN               NaN  ...                      NaN
# 4        Non-Fatal       Substantial   ...                      NaN
#
#    Total Minor Injuries   Total Uninjured   Weather Condition   \
# 0                    NaN               NaN                IMC
# 1                    NaN               NaN                 NaN
# 2                    NaN               NaN                 NaN
# 3                    NaN               NaN                 NaN
# 4                     1                NaN                 NaN
#
#    Broad Phase of Flight   Publication Date     Month Day   Year
# 0                     NaN        12/13/2013        12  08  2013
# 1                     NaN        12/13/2013        12  06  2013
# 2                     NaN                NaN       12  04  2013
# 3                     NaN                NaN       12  03  2013
# 4                     NaN        12/13/2013        12  02  2013
#
# [5 rows x 30 columns]

# %% [markdown]
# ### Location

# %%
# Location
data[['Location_City','Location_State']] = data[' Location '].str.split(',',expand=True)[[0,1]]
data[[' Location ','Location_City','Location_State']].head()
# Out:
#               Location     Location_City Location_State
# 0     Jacksonville, FL      Jacksonville            FL
# 1          Sebring, FL           Sebring            FL
# 2         Soldotna, AK          Soldotna            AK
# 3   Hendersonville, NC    Hendersonville            NC
# 4          Trenton, SC           Trenton            SC

# %% [markdown]
# ### Now that the data has been handled the way I wanted it to, we can drop the columns that have been transformed:

# %%
data.drop([' Location ', ' Event Date '], inplace = True, axis = 1)

# %%
data.head()
# Out:
#    Investigation Type          Country     Latitude     Longitude   \
# 0            Accident    United States    30.319723    -81.514167
# 1            Accident    United States    27.463333    -81.366667
# 2            Accident    United States           NaN           NaN
# 3            Accident    United States           NaN           NaN
# 4            Accident    United States    33.736944    -81.818611
#
#    Airport Code                      Airport Name   Injury Severity   \
# 0           CRG    Jacksonville Executive Airport              Fatal
# 1           SEF          Sebring Regional Airport              Fatal
# 2            NaN                               NaN               NaN
# 3            NaN                               NaN               NaN
# 4           6J6          Edgefield County Airport         Non-Fatal
#
#    Aircraft Damage   Aircraft Category                              Make   \
# 0      Substantial            Airplane                            CESSNA
# 1        Destroyed          Helicopter             TEXAS HELICOPTER CORP
# 2               NaN                 NaN                         BELLANCA
# 3               NaN                 NaN                 ANDERSON ANDREAS
# 4      Substantial            Airplane    MOFFITT OSCAR/ KIT PROSTAR A/C
#
#    ...  Total Uninjured   Weather Condition   Broad Phase of Flight   \
# 0  ...               NaN                IMC                      NaN
# 1  ...               NaN                 NaN                     NaN
# 2  ...               NaN                 NaN                     NaN
# 3  ...               NaN                 NaN                     NaN
# 4  ...               NaN                 NaN                     NaN
#
#    Publication Date     Month Day   Year    Location_City Location_State
# 0        12/13/2013        12  08  2013      Jacksonville            FL
# 1        12/13/2013        12  06  2013           Sebring            FL
# 2                NaN       12  04  2013          Soldotna            AK
# 3                NaN       12  03  2013    Hendersonville            NC
# 4        12/13/2013        12  02  2013           Trenton            SC
#
# [5 rows x 30 columns]

# %% [markdown]
# # Exploration

# %% [markdown]
# ### Location of Accidents

# %%
data['Latitude'] = data[' Latitude '].astype("float64")
data['Longitude'] = data[' Longitude '].astype("float64")
data.head()
# Out:
#    Investigation Type          Country     Latitude     Longitude   \
# 0            Accident    United States    30.319723    -81.514167
# 1            Accident    United States    27.463333    -81.366667
# 2            Accident    United States           NaN           NaN
# 3            Accident    United States           NaN           NaN
# 4            Accident    United States    33.736944    -81.818611
#
#    Airport Code                      Airport Name   Injury Severity   \
# 0           CRG    Jacksonville Executive Airport              Fatal
# 1           SEF          Sebring Regional Airport              Fatal
# 2            NaN                               NaN               NaN
# 3            NaN                               NaN               NaN
# 4           6J6          Edgefield County Airport         Non-Fatal
#
#    Aircraft Damage   Aircraft Category                              Make   \
# 0      Substantial            Airplane                            CESSNA
# 1        Destroyed          Helicopter             TEXAS HELICOPTER CORP
# 2               NaN                 NaN                         BELLANCA
# 3               NaN                 NaN                 ANDERSON ANDREAS
# 4      Substantial            Airplane    MOFFITT OSCAR/ KIT PROSTAR A/C
#
#    ...  Publication Date     Month Day   Year    Location_City Location_State  \
# 0  ...        12/13/2013        12  08  2013      Jacksonville            FL
# 1  ...        12/13/2013        12  06  2013           Sebring            FL
# 2  ...                NaN       12  04  2013          Soldotna            AK
# 3  ...                NaN       12  03  2013    Hendersonville            NC
# 4  ...        12/13/2013        12  02  2013           Trenton            SC
#
#     Latitude  Longitude Total Fatal Injuries
# 0  30.319723 -81.514167                  3.0
# 1  27.463333 -81.366667                  1.0
# 2        NaN        NaN                  NaN
# 3        NaN        NaN                  NaN
# 4  33.736944 -81.818611                  NaN
#
# [5 rows x 33 columns]

# %%
fig = px.scatter_geo(data, lat='Latitude', lon='Longitude')
fig.update_layout(title = 'World map of crashes', title_x=0.5)
fig.show()
# Out:
# <div>                            <div id="fe75a989-c873-4aae-bf4f-9bd1751fb0c1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fe75a989-c873-4aae-bf4f-9bd1751fb0c1")) {                    Plotly.newPlot(                        "fe75a989-c873-4aae-bf4f-9bd1751fb0c1",                        [{"geo":"geo","hovertemplate":"Latitude=%{lat}<br>Longitude=%{lon}<extra></extra>","lat":[30.319723,27.463333,null,null,33.736944,null,40.632223,null,48.52,38.811944,62.050833,33.603333,41.841666,32.615278,33.646944,null,null,37.7475,26.163333,null,null,35.014722,30.059444,29.332778,null,null,42.098333,null,40.010278,null,null,null,null,25.445,26.735277,35.250556,null,51.075278,36.2975,null,33.566667,null,39.558056,32.536389,33.818056,21.572778,-34.558889,-34.558889,44.745833,null,40.145833,null,34.5,33.970556,47.316667,50.2625,46.689722,46.689722,39.660278,null,null,36.154167,null,null,null,33.663611,19.728334,36.1075,45.224445,null,38.721111,45.56,39.424167,25.858333,27.514722,30.62,42.575556,31.145833,42.754444,38.591111,null,33.311389,35.700833,null,null,37.183611,null,null,32.112222,38.203333,33.214722,null,null,36.935833,35.23,null,null,null,null,-22.985277,34.618889,35.896389,null,null,null,32.570556,48.445833,null,-18.675834,28.017778,26.918889,28.228056,null,30.547222,40.039444,null,31.572223,null,37.5225,38.9,48.59,35.222223,40.764167,64.796111,null,42.983334,null,33.201111,39.721389,-34.628611,null,28.533334,26.117778,35.463056,null,32.667223,39.455556,34.16,52.095833,null,32.701944,44.75,38.506111,36.780278,null,30.121945,null,33.1625,null,null,null,null,34.848333,38.97,30.396666,null,null,59.376945,33.939444,15.062222,28.466667,18.25,43.577223,29.646389,null,null,40.820834,47.9,28.839444,null,32.72,31.549722,39.526389,32.958333,null,null,34.967223,34.015833,26.5225,null,39.933889,31.881111,43.075278,45.947777,34.263611,57.580278,44.723334,40.991389,26.068611,null,39.793889,35.368334,null,37.603889,41.691111,null,40.878334,null,61.536111,null,39.111111,48.299444,26.647222,42.015833,41.969723,null,31.863333,null,34.395277,34.740833,47.53,48.148889,2.0,43.798055,null,39.506389,null,53.352222,43.513611,32.61,33.978056,null,null,43.314167,64.561667,null,44.256667,44.7225,45.779167,-19.4725,null,32.955278,null,57.191666,36.687222,53.9725,45.56,35.081667,67.177778,59.440833,null,30.194444,36.191944,43.590555,40.041389,28.846666,33.734444,33.813611,-32.95,null,59.503333,null,44.290277,48.298333,40.333056,null,34.404444,null,31.639444,42.356667,null,44.124445,45.151389,38.009722,35.918056,35.511111,29.338333,42.009444,62.094444,40.77,35.863889,36.967223,null,39.57,null,26.586389,null,62.534444,61.918056,34.094722,null,29.046111,null,null,null,41.098055,62.079167,38.941389,41.724723,28.822223,null,44.304444,null,43.561111,null,36.52,39.908889,38.110278,45.765,48.097777,38.085555,36.780278,27.988889,33.037777,40.948333,33.741389,-2.312222,43.762778,null,null,35.738055,31.178334,34.812222,null,45.767778,62.2925,36.565278,26.197222,null,61.791111,null,33.986944,null,null,43.090555,39.25,null,39.701389,60.781945,61.208056,33.38,36.5975,25.403611,41.872778,41.067778,42.5925,41.639722,41.453889,35.211667,35.101111,48.470556,25.995,38.941111,39.595,39.595,43.169723,null,null,61.213333,null,38.797222,61.992777,62.320278,36.926389,43.564167,38.807222,36.124445,43.471111,40.030556,61.616389,43.8875,45.040277,40.006944,44.554444,47.542222,39.866667,null,42.114167,31.880278,46.434166,40.120278,null,39.180278,40.866111,35.108611,null,42.298889,61.700278,61.700278,36.705278,45.241389,null,null,45.055833,39.701111,29.521667,null,40.795555,62.956667,null,44.702778,38.271111,null,43.401944,34.376945,38.300556,41.570556,43.11,45.338333,null,61.904722,34.394444,34.663333,44.866667,38.543333,31.085833,45.865,43.628334,43.31 ...

# %% [markdown]
# ### Plotting Number of Accidents by each Year

# %%
plt.figure(figsize=(30,10))
plt.title("Number of Accidents per Year")
plt.plot(data.groupby("Year")[' Investigation Type '].count())

# %% [markdown]
# #### Linear Model of above plot

# %%
lmdata = pd.DataFrame(data.groupby("Year")[' Investigation Type '].count()).reset_index()
lmdata['Year'] = lmdata['Year'].astype("int")
sns.lmplot(data = lmdata.iloc[6:-1], x = 'Year', y = ' Investigation Type ')

# %% [markdown]
# This suggests a downwards trend in the number of accidents that are occuring over the years.

# %% [markdown]
# ### Plotting the Number of Fatalities per Year

# %%
data['Total Fatal Injuries'] = data[' Total Fatal Injuries '].astype("float")
plt.figure(figsize=(30,10))
plt.title("Number of Fatalities per Year")
plt.plot(data.groupby("Year")['Total Fatal Injuries'].sum())

# %% [markdown]
# #### Linear Model of above Plot

# %%
lmdata2 = pd.DataFrame(data.groupby("Year")['Total Fatal Injuries'].sum()).reset_index()
lmdata2['Year'] = lmdata2['Year'].astype("int")
sns.lmplot(data = lmdata2.iloc[6:-1], x = 'Year', y = 'Total Fatal Injuries')

# %% [markdown]
# This suggests that there has been no changes to the number of Fatalities over the years.
